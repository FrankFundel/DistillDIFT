# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Exploring Datasets

# %% [markdown]
# There are seperate dataset classes and download bash scripts for each evaluation dataset.
#
# Additionally, datasets can be preprocessed into HDF5 files (see README) and loaded with the PreprocessedDataset class.

# %%
from dataset import PreprocessedDataset, PFWillowDataset, SPairDataset
from utils.visualization import display_image_pair

# %%
from_hdf5 = True

if from_hdf5:
    spair_dataset = PreprocessedDataset('/export/group/datasets/SPair-71k/spair71k.h5')
    pfwillow_dataset = PreprocessedDataset('../data/PF-WILLOW/pfwillow.h5')
else:
    spair_dataset = SPairDataset('/export/group/datasets/SPair-71k')
    pfwillow_dataset = PFWillowDataset('../data/PF-WILLOW', '../data/PF-WILLOW/test_pairs_pf.csv')

# %%
# Get the first image pair from each dataset
spair_image_pair = spair_dataset[0]
pfwillow_image_pair = pfwillow_dataset[0]

# %%
print('SPair-71k')
display_image_pair(spair_image_pair)

print('PF-WILLOW')
display_image_pair(pfwillow_image_pair)
# Out:
# SPair-71k
# PF-WILLOW
